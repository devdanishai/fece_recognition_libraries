# %% [markdown]
# date:05/12/2024
# this is deepface library test code
# https://github.com/serengil/deepface?tab=readme-ov-file

# %%
#python==3.10.12
# !pip install deepface==0.0.93 -q

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip show deepface
# Out:
# Name: deepface
# Version: 0.0.93
# Summary: A Lightweight Face Recognition and Facial Attribute Analysis Framework (Age, Gender, Emotion, Race) for Python
# Home-page: https://github.com/serengil/deepface
# Author: Sefik Ilkin Serengil
# Author-email: serengil@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: fire, Flask, flask-cors, gdown, gunicorn, keras, mtcnn, numpy, opencv-python, pandas, Pillow, requests, retina-face, tensorflow, tqdm
# Required-by:

# %%
from deepface import DeepFace

# %%
result = DeepFace.verify(
  img1_path = "/content/fawad-khan.jpeg",
  img2_path = "/content/fawad-khan2.jpeg",
)

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.646283254992656,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 96,
#    'y': 34,
#    'w': 103,
#    'h': 103,
#    'left_eye': (165, 74),
#    'right_eye': (122, 77)},
#   'img2': {'x': 100,
#    'y': 42,
#    'w': 111,
#    'h': 111,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 2.48}

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

# Verify images
result = DeepFace.verify(
    img1_path = "/content/fawad-khan.jpeg",
    img2_path = "/content/fawad-khan2.jpeg",
)

# Print the result (optional)
print(result)

# Load images using OpenCV
img1 = cv2.imread("/content/fawad-khan.jpeg")
img2 = cv2.imread("/content/fawad-khan2.jpeg")

# Convert BGR (OpenCV format) to RGB (for correct display)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# Display images using matplotlib
plt.figure(figsize=(10, 5))

# Display the first image
plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.title("Image 1")
plt.axis('off')

# Display the second image
plt.subplot(1, 2, 2)
plt.imshow(img2)
plt.title("Image 2")
plt.axis('off')

plt.show()
# Out:
# {'verified': True, 'distance': 0.646283254992656, 'threshold': 0.68, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 96, 'y': 34, 'w': 103, 'h': 103, 'left_eye': (165, 74), 'right_eye': (122, 77)}, 'img2': {'x': 100, 'y': 42, 'w': 111, 'h': 111, 'left_eye': None, 'right_eye': None}}, 'time': 1.38}
